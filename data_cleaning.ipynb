# %%
import pandas as pd

# %%
# read data
df = pd.read_csv("sampled_crime_data.csv")

# %%
df.dtypes
# Out:
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# Ward                    float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Latitude                float64
# Longitude               float64
# Location                 object
# ID                      float64
# District                float64
# Community Area          float64
# Updated On               object
# dtype: object

# %%
# required datetime conversion
df['Date'] = df['Date'].astype('datetime64[ns]')
df['Updated On'] = df['Updated On'].astype('datetime64[ns]')

# integer type conversion
df['ID'] = df['ID'].astype('Int64')
df['Ward'] = df['Ward'].astype('Int64')
df['District'] = df['District'].astype('Int64')
df['Community Area'] = df['Community Area'].astype('Int64')

# categorical conversion
df["Primary Type"] = df["Primary Type"].astype("category", )
df["Description"] = df["Description"].astype("category")
df["Location Description"] = df["Location Description"].astype("category")
df["FBI Code"] = df["FBI Code"].astype("category")
df["Block"] = df["Block"].astype("category")
df["IUCR"] = df["IUCR"].astype("category")

# %%
df.dtypes

# %%
df.isna().sum()
# Out:
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description    2204
# Arrest                     0
# Domestic                   0
# Beat                       0
# Ward                       1
# FBI Code                   0
# X Coordinate            2098
# Y Coordinate            2098
# Year                       0
# Latitude                2098
# Longitude               2098
# Location                2098
# ID                         0
# District                   0
# Community Area            14
# Updated On                 0
# dtype: int64

# %%
# since null values are less than 5% we are dropping rows with null values

df = df.dropna(subset=["X Coordinate"])
df = df.dropna(subset=["Community Area"])
df = df.dropna(subset=["Location Description"])

# %%
df.isna().sum()
# Out:
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# Ward                    0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Latitude                0
# Longitude               0
# Location                0
# ID                      0
# District                0
# Community Area          0
# Updated On              0
# dtype: int64

# %%
df. shape
# Out:
# (497902, 22)

# %%
df.head()
# Out:
#   Case Number       Date                 Block  IUCR        Primary Type  \
# 0    JK184891 2026-03-18   069XX S CORNELL AVE  0486             BATTERY
# 1    JK184982 2026-03-18   082XX S CORNELL AVE  0820               THEFT
# 2    JK188256 2026-03-18  034XX N RIDGEWAY AVE  0810               THEFT
# 4    JK186910 2026-03-18     072XX S DAMEN AVE  1130  DECEPTIVE PRACTICE
# 5    JK185040 2026-03-18   032XX N RICHMOND ST  0760            BURGLARY
#
#                    Description    Location Description  Arrest  Domestic  \
# 0      DOMESTIC BATTERY SIMPLE               APARTMENT   False      True
# 1               $500 AND UNDER  VEHICLE NON-COMMERCIAL   False     False
# 2                    OVER $500               RESIDENCE   False     False
# 4     FRAUD OR CONFIDENCE GAME               RESIDENCE   False     False
# 5  BURGLARY FROM MOTOR VEHICLE                  STREET   False     False
#
#    Beat  Ward FBI Code  X Coordinate  Y Coordinate  Year   Latitude  \
# ...

# %%
df.tail()
# Out:
#        Case Number                Date                 Block  IUCR  \
# 499995    JH168561 2024-02-28 06:05:00   038XX N ASHLAND AVE  0610
# 499996    JH171253 2024-02-28 06:00:00      056XX W BYRON ST  0810
# 499997    JH169057 2024-02-28 06:00:00  060XX S OAK PARK AVE  0820
# 499998    JH169158 2024-02-28 06:00:00   017XX S INDIANA AVE  0890
# 499999    JH169156 2024-02-28 06:00:00   017XX S INDIANA AVE  0890
#
#        Primary Type     Description Location Description  Arrest  Domestic  \
# 499995     BURGLARY  FORCIBLE ENTRY        BAR OR TAVERN   False     False
# 499996        THEFT       OVER $500            RESIDENCE   False     False
# 499997        THEFT  $500 AND UNDER               STREET   False     False
# 499998        THEFT   FROM BUILDING            APARTMENT   False     False
# 499999        THEFT   FROM BUILDING            APARTMENT   False     False
#
#         Beat  Ward FBI Code  X Coordinate  Y Coordinate  Year   Latitude  \
# ...

# %%
df['Arrest'].unique()
# Out:
# array([False,  True])

# %%
df['IUCR'].unique()[:30]
# Out:
# array(['0486', '0820', '0810', '0460', '1130', '0760', '1153', '1320',
#        '0496', '0560', '1330', '1310', '1477', '5111', '0910', '3731',
#        '0710', '0430', '2825', '143A', '0860', '051A', '0930', '2870',
#        '141A', '0326', '5002', '502R', '5112', '2022'], dtype=object)

# %%
df['Community Area'].unique()[:40]
# Out:
# array([43., 45., 21., 25., 67., 13., 32., 49., 22., 66.,  8., 29., 31.,
#         3., 64., 28., 48., 63., 24., 19.,  6.,  2., 42.,  5., 27., 33.,
#        51., 76., 15., 37., 16., 44., 35., 30., 61., 77., 23., 73., 34.,
#        60.])

# %%
df['FBI Code'].unique()
# Out:
# array(['08B', '06', '11', '14', '04B', '08A', '26', '15', '07', '24',
#        '04A', '03', '18', '01A', '20', '17', '02', '05', '09', '10', '16',
#        '13', '22', '12', '19', '01B'], dtype=object)

# %%
df['ID'].unique()
# Out:
# array([14139805., 14139911., 14142669., ..., 13382822., 13383190.,
#        13383165.], shape=(500000,))

# %%
df[df['Case Number'].duplicated(keep=False)]
# Out:
#        Case Number                Date                 Block  IUCR  \
# 4987      JK174465 2026-03-09 03:41:00    050XX S JUSTINE ST  0110
# 5024      JK174465 2026-03-09 01:03:00    050XX S JUSTINE ST  0110
# 5666      JK173315 2026-03-07 23:20:00     104XX S PEORIA ST  0110
# 5667      JK173315 2026-03-07 23:20:00     104XX S PEORIA ST  0110
# 24257     JK137074 2026-02-03 14:03:00  023XX W ROOSEVELT RD  0110
# ...            ...                 ...                   ...   ...
# 477479    JH208794 2024-04-01 11:41:00      007XX E 104TH ST  0110
# 490496    JH185734 2024-03-13 00:40:00      002XX W 109TH PL  0110
# 490497    JH185734 2024-03-13 00:40:00      002XX W 109TH PL  0110
# 490829    JH185103 2024-03-12 15:45:00      069XX S STATE ST  0110
# 490832    JH185103 2024-03-12 15:45:00      069XX S STATE ST  0110
#
#        Primary Type          Description Location Description  Arrest  \
# 4987       HOMICIDE  FIRST DEGREE MURDER               STREET   False
# ...

# %%
# drop duplicate rows with the same case number as we are interested in crime ocurence
df = df.drop_duplicates(subset=["Case Number"], keep="first")

# %%
# this will check for any other duplicates

df[df['Case Number'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, Ward, FBI Code, X Coordinate, Y Coordinate, Year, Latitude, Longitude, Location, ID, District, Community Area, Updated On]
# Index: []

# %%
# save the cleaned file as .pkl to conserve column datatypes

df.to_pickle("cleaned_chicago_crime_data.pkl")
